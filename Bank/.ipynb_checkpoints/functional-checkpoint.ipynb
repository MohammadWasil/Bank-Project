# %%
import pandas as pd
from pymongo import MongoClient 
import os, json, csv
import pprint

# %%
# mongodb+srv://bank:<password>@bank-analytics.jrwtb.mongodb.net/<dbname>?retryWrites=true&w=majority
client = MongoClient("mongodb+srv://bank:bank@bank-analytics.jrwtb.mongodb.net/bank?retryWrites=true&w=majority")

# %%
db = client.Bank

# %%
coll = db.CustomerTransactions

# %%
client = MongoClient("mongodb://localhost:27017/")

# %%
client.Bank["Usernames"]
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Bank'), 'Usernames')

# %%
# Creating a client 
client = MongoClient("mongodb://localhost:27017/") 
  
# Greating a database name GFG 
database = client["Bank"] 
print("Database is created !!")

collection = database["CustomerTransactions"]
print("Collection is created")
# Out:
# Database is created !!
# Collection is created

# %%
collection.CustomerTransactions
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Bank'), 'CustomerTransactions.CustomerTransactions')

# %%
# To check if the database is created or not.
list_of_database = client.list_database_names() 

if "Bank" in list_of_database: 
	print("Exists !!") 
    

# To check if the collection is created.
list_of_collection = database.list_collection_names()
if "CustomerTransaction" in list_of_collection:
    print("Exists !!")
# Out:
# Exists !!

# %%
os.path.join(dir_path, excel_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-39a81cc3c062> in <module>
# ----> 1 os.path.join(dir_path, excel_file)
#
# NameError: name 'dir_path' is not defined

# %%
dir_path = "D:/ML/Tutorials/Git/Dockers/Groceries with card.xlsx"
csv_file = "D:/ML/Tutorials/Git/Dockers/Groceries with card.csv"

data = pd.read_excel (dir_path)
data.set_index("SNo", inplace=True)
data.to_csv(csv_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-77b29b462fab> in <module>
#       2 csv_file = "D:/ML/Tutorials/Git/Dockers/Groceries with card.csv"
#       3
# ----> 4 data = pd.read_excel (dir_path)
#       5 data.set_index("SNo", inplace=True)
#       6 data.to_csv(csv_file)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
data
# Out:
#           Date  Place                                               Item  \
# SNo
# 1   2020-01-01  Netto  apple juice, roma pudding, pizza, finton doppe...
# 2   2020-01-08  Netto                   oil, kechup, pizza, bread, pyaaz
# 3   2020-01-11  Netto                    Margherita Pizza, Pepsi, Banana
# 4   2020-01-14  Netto              Water, pizza, eggs, mozzarella cheese
# 5   2020-01-22  Netto                               Apple juice, 2 kubza
# ..         ...    ...                                                ...
# 79  2020-10-12  Netto  2 harry donuts, tomato puree, ketchup, strawbe...
# 80  2020-10-17  Netto  cocacola, big bread, khubza, lemon, apple, BOT...
# 81  2020-10-22  Netto                      bread big, basmati rice, rice
# 82  2020-10-22  Netto  pepsi, pizza margerita small, donut, pesto gen...
# 83  2020-10-27  Netto  bread, eggs, rice, bodywash X3, tomato paste, ...
#
#                                                 Amount          Total
# SNo
# ...

# %%
header= [ "SNo", "Date", "Place","Item", "Amount", "Total"]

with open(csv_file, encoding='utf-8') as csvf:

    reader = csv.DictReader( csvf, header)

    for each in reader:
        row={}
        for field in header:
            row[field]=each[field]
            
        database.CustomerTransactions.insert_one(row)

#

# %%
row
# Out:
# {'S. No': '83',
#  'Date': '2020-10-27',
#  'Place': 'Netto',
#  'Item': 'bread, eggs, rice, bodywash X3, tomato paste, cheese slice, curd, strawberry yogurt, gurke, condense milk, mayonaisse, tuna',
#  'Amount': '0.66+1.52+0.66+2.22+0.37+0.96+0.47+0.43+0.97+0.57+0.76+1.15',
#  'Total': '10.74'}

# %%
# Creating a client 
client = MongoClient("mongodb://localhost:27017/")

# %%
database = client.Bank # get the database

# %%
col = database.CustomerTransactions # get the collection

# %%
col.find_one({'SNo': 1})
# Out:
# {'_id': ObjectId('5fefc7e6a49df2c38d97b20c'),
#  'SNo': 1,
#  'Date': '2020-01-01 00:00:00',
#  'Place': 'Netto',
#  'Item': 'apple juice, roma pudding, pizza, finton doppelkeks',
#  'Amount': '0.79+0.25+0.35+0.79+0.99',
#  'Total': 3.17}

# %%
for post in col.find():
    print(post)
# Out:
# {'_id': ObjectId('5fefc7e6a49df2c38d97b20b'), 'SNo': 'SNo', 'Date': 'Date', 'Place': 'Place', 'Item': 'Item', 'Amount': 'Amount', 'Total': 'Total'}
# {'_id': ObjectId('5fefc7e6a49df2c38d97b20c'), 'SNo': 1, 'Date': '2020-01-01 00:00:00', 'Place': 'Netto', 'Item': 'apple juice, roma pudding, pizza, finton doppelkeks', 'Amount': '0.79+0.25+0.35+0.79+0.99', 'Total': 3.17}
# {'_id': ObjectId('5fefc7e6a49df2c38d97b20d'), 'SNo': 2, 'Date': '2020-01-08 00:00:00', 'Place': 'Netto', 'Item': 'oil, kechup, pizza, bread, pyaaz', 'Amount': '0.99+1.29+0.79+0.59+0.69', 'Total': 4.35}
# {'_id': ObjectId('5fefc7e6a49df2c38d97b20e'), 'SNo': 3, 'Date': '2020-01-11 00:00:00', 'Place': 'Netto', 'Item': 'Margherita Pizza, Pepsi, Banana', 'Amount': '0.79+0.95+0.25+0.94', 'Total': 2.93}
# {'_id': ObjectId('5fefc7e6a49df2c38d97b20f'), 'SNo': 4, 'Date': '2020-01-14 00:00:00', 'Place': 'Netto', 'Item': 'Water, pizza, eggs, mozzarella cheese', 'Amount': '0.19+0.25+0.79+1.43+1.40', 'Total': 4.06}
# ...

# %%
collection = client.Bank.CustomerTransactions

# %%
row = collection.find_one({'SNo': 'SNo'})
row
# Out:
# {'_id': ObjectId('5fefc7e6a49df2c38d97b20b'),
#  'SNo': 'SNo',
#  'Date': 'Date',
#  'Place': 'Place',
#  'Item': 'Item',
#  'Amount': 'Amount',
#  'Total': 'Total'}

# %%
# To deletet the first row.
collection.remove

# %%
pipeline = [
    {
        '$filter' : {
            'input' : '_id',
            'as'    : '_id',
            'cond'  : { '$eq' : { "SNo", 'SNo'}}
        }
    }
    
]
print(list(client.database.collection.aggregate(pipeline)))
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# <ipython-input-28-dbc756c6533c> in <module>
#       9
#      10 ]
# ---> 11 print(list(client.database.collection.aggregate(pipeline)))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\collection.py in aggregate(self, pipeline, session, **kwargs)
#    2456                                    session=s,
#    2457                                    explicit_session=session is not None,
# -> 2458                                    **kwargs)
#    2459
#    2460     def aggregate_raw_batches(self, pipeline, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, **kwargs)
#    2375         return self.__database.client._retryable_read(
#    2376             cmd.get_cursor, cmd.get_read_preference(session), session,
# ...

# %%
for col in row:
    print(row[col])
# Out:
# 5f98977f4e6d9ffd72f449bd
# 1
# 2020-01-01
# Netto
# apple juice, roma pudding, pizza, finton doppelkeks
# 0.79+0.25+0.35+0.79+0.99
# 3.17

# %%
row = collection.find()
row

for doc in row:
    for col in doc:
        print(doc[col])
# Out:
# 5f98977f4e6d9ffd72f449bd
# 1
# 2020-01-01
# Netto
# apple juice, roma pudding, pizza, finton doppelkeks
# 0.79+0.25+0.35+0.79+0.99
# 3.17
# 5f98977f4e6d9ffd72f449be
# 2
# 2020-01-08
# Netto
# oil, kechup, pizza, bread, pyaaz
# 0.99+1.29+0.79+0.59+0.69
# 4.35
# 5f98977f4e6d9ffd72f449bf
# 3
# 2020-01-11
# Netto
# Margherita Pizza, Pepsi, Banana
# 0.79+0.95+0.25+0.94
# 2.93
# 5f98977f4e6d9ffd72f449c0
# 4
# 2020-01-14
# Netto
# Water, pizza, eggs, mozzarella cheese
# 0.19+0.25+0.79+1.43+1.40
# 4.06
# 5f98977f4e6d9ffd72f449c1
# 5
# 2020-01-22
# Netto
# Apple juice, 2 kubza
# 0.79+0.25+0.32
# 1.36
# 5f98977f4e6d9ffd72f449c2
# 6
# 2020-01-23
# Netto
# Pizza, eggs, FA Men Ocean(Face Wash)
# 0.79+1.55+1.99
# 4.33
# 5f98977f4e6d9ffd72f449c3
# 7
# 2020-01-14
# Amazon
# CFL Light bulb
# 5.27
# 5.27
# 5f98977f4e6d9ffd72f449c4
# 8
# 2020-01-24
# Eurogida
# Chicken, Keema, brot
# 6.45+1.88+1.79
# 10.12
# 5f98977f4e6d9ffd72f449c5
# 9
# 2020-01-26
# Netto
# Bread, biscuit, tomato
# 0.69+0.99+1.39
# ...

# %%
input_u = "Wasil11"
input_p = "something11"

collection_username = client.Bank.Usernames              # collection/table of customer transaction

query_username = { "username" : "Wasil11"}
    
your_username = collection_username.find(query_username)
for name in your_username:
    print(name["username"])
    print(name["password"])
    
    if name["username"] == input_u:
        print("username is correct")
        if name["password"] == input_p:
            print("password is correct")
        else:
            print("password is wrong")
    else:
        print("username is wrong")
print(your_username)
# Out:
# Wasil11
# something11
# username is correct
# password is wrong
# ...

# %%
your_username

# %%
if "Wasil11" in your_username["username"]:
    print("yes")
# Out:
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# <ipython-input-20-428242f91be1> in <module>
# ----> 1 if "Wasil11" in your_username["username"]:
#       2     print("yes")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\cursor.py in __getitem__(self, index)
#     610           - `index`: An integer or slice index to be applied to this cursor
#     611         """
# --> 612         self.__check_okay_to_chain()
#     613         self.__empty = False
#     614         if isinstance(index, slice):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymongo\cursor.py in __check_okay_to_chain(self)
#     399         """
#     400         if self.__retrieved or self.__id is not None:
# --> 401             raise InvalidOperation("cannot set options after executing query")
#     402
#     403     def add_option(self, mask):
#
# ...

# %%
# Creating a connection with the MongoDB database
client = MongoClient("mongodb://localhost:27017/") 
collection_customer_transaction = client.Bank.CustomerTransactions   # collection/table of customer transaction
collection_username = client.Bank.Usernames              # collection/table of customer transaction

# %%
query_username = { "username" : "Wasil1"}

# Check if the user login and password are correct or not.
your_username = collection_username.find(query_username)

# %%
your_username

# %%
# Creating a database name "database" 
database = client["Bank"] 
print("Database is created !!")

# Creating a collection name "collection" 
collection = database["CustomerTransactions"]
print("Collection is created")
# Out:
# Database is created !!
# Collection is created

# %%
pipeline = [
    {
        "$limit" : 10,
    },
    {
        "$project" : 
        {
            {
              "Amount" : 
              {
                "$cond": 
                {
                    # If the number of items and size of AMount array are different, then definately there is some problem.
                  "if": { "$ne" :[ {"$size": "$Item"}, {"$size":"$Amount"}]    },
                  "then":  
                     {
                       "$cond" : 
                              {
                                  # Check if apple juice is in the item
                                "if" : { "$in" :[ "apple juice", "$Item" ] },
                                "then" : { 
                                        # Add the value of 0.25 to the original price of the apple juice.
                                        "$let":
                                            {
                                              vars: { "appleJuiceIndex": { "$indexOfArray": [ "$Item", "apple juice" ]} },
                                              in: { "$add" : [{"$arrayElemAt": ["$Amount", "$$appleJuiceIndex" ]}, 
                                                      {"$arrayElemAt": ["$Amount", { "$add": ["$$appleJuiceIndex", 1]  } ]}]      }
                                            }
                                    # Update the array
                                },
                                "else" : {"Amount" : 10},
                              }
                          },
                  "else": {"Amount" : 123123}
                }
              }
            }
        }   
    }
]
pprint.pprint(list(client.database.collection.aggregate(pipeline)))
# Out:
# []

# %%
{
  "Amount" : 
  {
    "$cond": 
    {
      "if": { "$eq" :[ {"$size": "$Item"}, {"$size":"$Amount"}] },
      "then": {"Amount" : 1},
      "else": {"Amount" : 0}
      
    }
  } 
}

"$let":
    {
      vars: { "appleJuiceIndex": { "$indexOfArray": [ "$Item", "apple juice" ]} },
      in: { "$add" : [{"$arrayElemAt": ["$Amount", "$$appleJuiceIndex" ]}, 
              {"$arrayElemAt": ["$Amount", { "$add": ["$$appleJuiceIndex", 1]  } ]}]      }
    }
    

    
#
"$let":
    {
      vars: { "appleJuiceIndex": { "$indexOfArray": [ "$Item", "apple juice" ]} },
      in: { "$add" : [{"$arrayElemAt": ["$Amount", "$$appleJuiceIndex" ]}, 
              {"$arrayElemAt": ["$Amount", { "$add": ["$$appleJuiceIndex", 1]  } ]}]   }
    }
    
#
"$add" : [{"$arrayElemAt": ["$Amount", { "$indexOfArray": [ "$Item", "apple juice" ]} ]}, 
                              {"$arrayElemAt": ["$Amount", { "$add": [{"$indexOfArray": [ "$Item", "apple juice" ]}, 1]  } ]}]
